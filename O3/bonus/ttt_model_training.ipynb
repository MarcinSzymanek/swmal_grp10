# %%
#!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RcblOwaZETwq19a8fyov")
#project = rf.workspace("swmal10").project("tictactoe-dzydr")
#dataset = project.version(1).download("yolov8")

#project = rf.workspace("swmal10").project("tictactoe-dzydr")
#dataset = project.version(2).download("yolov8")

# %%
from ultralytics import YOLO
import os
import platform
newmodel = YOLO("yolov8n.pt")

# %%
res = newmodel.train(data="/home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/data.yaml")
newmodel.train(data="/home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-2/data.yaml")
# Out:
# Ultralytics YOLOv8.0.209 🚀 Python-3.9.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12043MiB)
# ...

# %%
res = newmodel.predict(source="/home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/test/images", save=True)
res = newmodel.predict(source="/home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-2/test/images", save=True)
# Out:
# image 1/3 /home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/test/images/IMG_20231114_222901_jpg.rf.a30973f35379ad7641e535eb2248fb95.jpg: 640x640 1 Board, 5 Circles, 3 Crosss, 5.3ms
# image 2/3 /home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/test/images/IMG_20231114_222915_jpg.rf.96206f00de7a7abdebe6f2c4c69e7e78.jpg: 640x640 1 Board, 5 Circles, 4 Crosss, 4.6ms
# image 3/3 /home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/test/images/IMG_20231114_223119_jpg.rf.2c2ebab8846c85ce213e7ae1a28575cc.jpg: 640x640 1 Board, 5 Circles, 4 Crosss, 4.4ms
# Speed: 1.0ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train622
#
# image 1/2 /home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-2/test/images/IMG_20231114_222901_jpg.rf.cc0d8a121a624dda727bc30ee6f5c64e.jpg: 416x640 1 Board, 5 Circles, 3 Crosss, 68.8ms
# ...

# %%
from ultralytics import YOLO
best = YOLO('/home/swmal10e23/swmal_grp10/O3/marcin/runs/detect/train5/weights/best.pt')  # load a custom trained model

# Export the model
best.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.209 🚀 Python-3.9.12 torch-2.1.0+cu121 CPU (AMD Ryzen 9 5900X 12-Core Processor)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/home/swmal10e23/swmal_grp10/O3/marcin/runs/detect/train5/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 0.4s, saved as '/home/swmal10e23/swmal_grp10/O3/marcin/runs/detect/train5/weights/best.onnx' (11.7 MB)
#
# Export complete (27.1s)
# Results saved to /home/swmal10e23/swmal_grp10/O3/marcin/runs/detect/train5/weights
# Predict:         yolo predict task=detect model=/home/swmal10e23/swmal_grp10/O3/marcin/runs/detect/train5/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/home/swmal10e23/swmal_grp10/O3/marcin/runs/detect/train5/weights/best.onnx imgsz=640 data=/home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/data.yaml
# ...

# %%
import pkg_resources
import sys
sys.path.append("/home/swmal10e23/.local/lib/python3.9/site-packages")
pkg_resources.require("torchvision==0.16")
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)

model = YOLO('/home/swmal10e23/swmal_grp10/O3/marcin/runs/detect/train5/weights/best.onnx')

res = model.predict(source="/home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/test/images", save=True)
res = model.predict(source="/home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-2/test/images", save=True)
# Out:
# Loading /home/swmal10e23/swmal_grp10/O3/marcin/runs/detect/train5/weights/best.onnx for ONNX Runtime inference...
# 2.1.0+cu121
# 0.16.0+cu121
# image 1/3 /home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/test/images/IMG_20231114_222901_jpg.rf.a30973f35379ad7641e535eb2248fb95.jpg: 640x640 2 Boards, 5 Circles, 2 Crosss, 149.8ms
# image 2/3 /home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/test/images/IMG_20231114_222915_jpg.rf.96206f00de7a7abdebe6f2c4c69e7e78.jpg: 640x640 2 Boards, 5 Circles, 3 Crosss, 113.9ms
# image 3/3 /home/swmal10e23/swmal_grp10/O3/marcin/TicTacToe-1/test/images/IMG_20231114_223119_jpg.rf.2c2ebab8846c85ce213e7ae1a28575cc.jpg: 640x640 5 Boards, 5 Circles, 6 Crosss, 110.9ms
# Speed: 4.2ms preprocess, 124.9ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
#
# ...
